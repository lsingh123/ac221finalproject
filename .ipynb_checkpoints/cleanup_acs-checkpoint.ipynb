# %%
import csv

dic = 'data/PUMSDataDict15.txt'
file = 'data/ss15pusa/ss15pusa.csv'

with open(dic, 'r', encoding='mac_roman', newline='') as fi:
    index = -1
    line = fi.readline()
    flag = False
    prev = None
    while (line):
        if not flag and (line.find('PERSON RECORD') != -1):
            flag = True
            continue
        if flag and line[0:3].isupper() and line[0:2].find(' ') == -1 and prev=="\n":
            print(index, line)
            index += 1
        line = fi.readline()
# Out:
# -1 PERSON RECORD
#
# 0 RT		1
#
# 1 		P .Person Record
#
# 2 SERIALNO   	7
#
# 3 SPORDER		2
#
# 4 PUMA		5
#
# 5 ST		2
#
# 6 ADJINC		7
#
# 7 PWGTP		5
#
# 8 AGEP		2
#
# 9 CIT		1
#
# 10 CITWP		4
#
# 11 COW		1
#
# 12 DDRS		1
#
# 13 DEAR		1
#
# 14 DEYE		1
#
# 15 DOUT		1
#
# 16 DPHY		1
#
# 17 DRAT		1
#
# 18 DRATX		1
#
# 19 DREM		1
#
# 20 ENG		1
#
# 21 FER		1
#
# 22 GCL		1
#
# 23 GCM		1
#
# 24 GCR		1
#
# 25 HINS1		1
#
# 26 HINS2		1
#
# 27 HINS3		1
#
# 28 HINS4		1
#
# 29 HINS5		1
#
# 30 	TRICARE or other military health care
#
# 31 HINS6		1
#
# 32 	VA (including those who have ever used or enrolled for VA health care)
#
# 33 HINS7		1
#
# 34 INTP		6
#
# 35 JWMNP		3
#
# 36 JWRIP		2
#
# 37 JWTR		2
#
# 38 LANX		1
#
# 39 MAR		1
#
# 40 MARHD		1
#
# 41 MARHM		1
#
# 42 MARHT		1
#
# 43 MARHW		1
#
# 44 MARHYP		4
#
# 45 MIG		1
#
# 46 MIL		1
#
# 47 MLPA		1
#
# 48 MLPB		1
#
# 49 MLPCD		1
#
# 50 MLPE		1
#
# 51 MLPFG		1
#
# 52 MLPH		1
#
# 53 MLPI		1
#
# 54 MLPJ		1
#
# 55 MLPK		1
#
# 56 NWAB		1 (UNEDITED - See "Employment Status Recode" (ESR))
#
# 57 NWAV		1 (UNEDITED - See "Employment Status Recode" (ESR))
#
# 58 NWLA		1 (UNEDITED - See "Employment Status Recode" (ESR))
#
# 59 NWLK		1 (UNEDITED - See ìEmployment Status Recodeî (ESR))
#
# 60 NWRE		1 (UNEDITED - See ìEmployment Status Recodeî (ESR))
#
# 61 OIP		6
#
# 62 PAP		5
#
# 63 RELP		2
#
# 64 RETP		6
#
# 65 SCH		1
#
# 66 SCHG		2
#
# 67 SCHL		2
#
# 68 SEMP		6
#
# 69 SEX		1
#
# 70 SSIP		5
#
# 71 SSP		5
#
# 72 WAGP		6
#
# 73 WKHP		2
#
# 74 WKL		1
#
# 75 WKW		1
#
# 76 WRK		1
#
# 77 YOEP		4
#
# 78 ANC		1
#
# 79 ANC1P		3
#
# 80 ANC2P		3
#
# 81 DECADE		1
#
# 82 DIS		1
#
# 83 DRIVESP		1
#
# 84 ESP		1
#
# 85 ESR		1
#
# 86 FOD1P		4
#
# 87 FOD2P		4
#
# 88 HICOV		1
#
# 89 HISP		2
#
# 90 INDP		4
#
# 91 JWAP		3
#
# 92 JWDP		3
#
# 93 LANP		3
#
# 94 MIGPUMA		5
#
# 95 MIGSP		3
#
# 96 MSP		1
#
# 97 NAICSP	8
#
# 98 	NAICS Industry recode for 2013 and later based on 2012 NAICS codes
#
# 99 NATIVITY	1
#
# 100 NOP		1
#
# 101 OC		1
#
# 102 OCCP		4
#
# 103 PAOC		1
#
# 104 PERNP		7
#
# 105 PINCP		7
#
# 106 POBP		3
#
# 107 POVPIP		3
#
# 108 POWPUMA		5
#
# 109 POWSP		3
#
# 110 PRIVCOV		1
#
# 111 PUBCOV		1
#
# 112 QTRBIR		1
#
# 113 RAC1P		1
#
# 114 RAC2P		2
#
# 115 RAC3P		3
#
# 116 RACAIAN		1
#
# 117 RACASN		1
#
# 118 RACBLK		1
#
# 119 RACNH		1
#
# 120 RACNUM		1
#
# 121 RACPI		1
#
# 122 RACSOR		1
#
# 123 RACWHT		1
#
# 124 RC		1
#
# 125 SCIENGP		1
#
# 126 SCIENGRLP	1
#
# 127 SFN		1
#
# 128 SFR		1
#
# 129 SOCP		6
#
# 130 	SOC Occupation code for 2012 and later based on 2010 SOC codes
#
# 131 VPS		2
#
# 132 WAOB		1
#
# 133 FAGEP		1
#
# 134 FANCP		1
#
# 135 FCITP		1
#
# 136 FCITWP		1
#
# 137 FCOWP		1
#
# 138 FDDRSP		1
#
# 139 FDEARP		1
#
# 140 FDEYEP		1
#
# 141 FDISP		1
#
# 142 FDOUTP		1
#
# 143 FDPHYP		1
#
# 144 FDRATP		1
#
# 145 FDRATXP		1
#
# 146 FDREMP		1
#
# 147 FENGP		1
#
# 148 FESRP		1
#
# 149 FFERP		1
#
# 150 FFODP		1
#
# 151 FGCLP		1
#
# 152 FGCMP		1
#
# 153 FGCRP		1
#
# 154 FHICOVP		1
#
# 155 FHINS1P		1
#
# 156 FHINS2P		1
#
# 157 FHINS3C		1
#
# 158 FHINS3P		1
#
# 159 FHINS4C		1
#
# 160 FHINS4P		1
#
# 161 FHINS5C		1
#
# 162 	TRICARE coverage given through the eligibility coverage edit
#
# 163 FHINS5P		1
#
# 164 	TRICARE or other military health care allocation flag
#
# 165 FHINS6P		1
#
# 166 	VA (including those who have ever used or enrolled for VA health care)
#
# 167 FHINS7P		1
#
# 168 FHISP		1
#
# 169 FINDP		1
#
# 170 FINTP		1
#
# 171 FJWDP		1
#
# 172 FJWMNP		1
#
# 173 FJWRIP		1
#
# 174 FJWTRP		1
#
# 175 FLANP		1
#
# 176 FLANXP		1
#
# 177 FMARP		1
#
# 178 FMARHDP		1
#
# 179 FMARHMP		1
#
# 180 FMARHTP		1
#
# 181 FMARHWP		1
#
# 182 FMARHYP		1
#
# 183 FMIGP		1
#
# 184 FMIGSP		1
#
# 185 FMILPP		1
#
# 186 FMILSP		1
#
# 187 FOCCP		1
#
# 188 FOIP		1
#
# 189 FPAP		1
#
# 190 FPERNP		1
#
# 191 FPINCP		1
#
# 192 FPOBP		1
#
# 193 FPOWSP		1
#
# 194 FPRIVCOVP 	 1
#
# 195 FPUBCOVP  	1
#
# 196 FRACP		1
#
# 197 FRELP		1
#
# 198 FRETP		1
#
# 199 FSCHGP		1
#
# 200 FSCHLP		1
#
# 201 FSCHP		1
#
# 202 FSEMP		1
#
# 203 FSEXP		1
#
# 204 FSSIP		1
#
# 205 FSSP		1
#
# 206 FWAGP		1
#
# 207 FWKHP		1
#
# 208 FWKLP		1
#
# 209 FWKWP		1
#
# 210 FWRKP		1
#
# 211 FYOEP		1
#
# 212 PWGTP1		5
#
# 213 PWGTP2		5
#
# 214 PWGTP3		5
#
# 215 PWGTP4		5
#
# 216 PWGTP5		5
#
# 217 PWGTP6		5
#
# 218 PWGTP7		5
#
# 219 PWGTP8		5
#
# 220 PWGTP9		5
#
# 221 PWGTP10		5
#
# 222 PWGTP11		5
#
# 223 PWGTP12		5
#
# 224 PWGTP13		5
#
# 225 PWGTP14		5
#
# 226 PWGTP15		5
#
# 227 PWGTP16		5
#
# 228 PWGTP17		5
#
# 229 PWGTP18		5
#
# 230 PWGTP19		5
#
# 231 PWGTP20		5
#
# 232 PWGTP21		5
#
# 233 PWGTP22		5
#
# 234 PWGTP23		5
#
# 235 PWGTP24		5
#
# 236 PWGTP25		5
#
# 237 PWGTP26		5
#
# 238 PWGTP27		5
#
# 239 PWGTP28		5
#
# 240 PWGTP29		5
#
# 241 PWGTP30		5
#
# 242 PWGTP31		5
#
# 243 PWGTP32		5
#
# 244 PWGTP33		5
#
# 245 PWGTP34		5
#
# 246 PWGTP35		5
#
# 247 PWGTP36		5
#
# 248 PWGTP37		5
#
# 249 PWGTP38		5
#
# 250 PWGTP39		5
#
# 251 PWGTP40		5
#
# 252 PWGTP41		5
#
# 253 PWGTP42		5
#
# 254 PWGTP43		5
#
# 255 PWGTP44		5
#
# 256 PWGTP45		5
#
# 257 PWGTP46		5
#
# 258 PWGTP47		5
#
# 259 PWGTP48		5
#
# 260 PWGTP49		5
#
# 261 PWGTP50		5
#
# 262 PWGTP51		5
#
# 263 PWGTP52		5
#
# 264 PWGTP53		5
#
# 265 PWGTP54		5
#
# 266 PWGTP55		5
#
# 267 PWGTP56		5
#
# 268 PWGTP57		5
#
# 269 PWGTP58		5
#
# 270 PWGTP59		5
#
# 271 PWGTP60		5
#
# 272 PWGTP61		5
#
# 273 PWGTP62		5
#
# 274 PWGTP63		5
#
# 275 PWGTP64		5
#
# 276 PWGTP65		5
#
# 277 PWGTP66		5
#
# 278 PWGTP67		5
#
# 279 PWGTP68		5
#
# 280 PWGTP69		5
#
# 281 PWGTP70		5
#
# 282 PWGTP71		5
#
# 283 PWGTP72		5
#
# 284 PWGTP73		5
#
# 285 PWGTP74		5
#
# 286 PWGTP75		5
#
# 287 PWGTP76		5
#
# 288 PWGTP77		5
#
# 289 PWGTP78		5
#
# 290 PWGTP79		5
#
# 291 PWGTP80		5
#
# 292 SOC occupation codes were aggregated to correspond to a specific Census
#
# 293 	M = Multiple NAICS codes
#
# 294 	P = Part of a NAICS code - NAICS code split between two or more Census
#
# 295 	S = Not specified Industry in NAICS sector - Specific to Census codes
#
# 296 	Z = Exception to NAICS code - Part of NAICS industry but has a unique

# %%
indeces = [0, 6, 8, 11, 17, 30, 31, 37, 43, 45, 47, 48, 51, 52, 54, 59, 62, 65, 70, 71, 72, 78, 79, 198, 200, 201, 202,
         220, 222, 223, 224, 227, 228, 231, 235, 236, 251, 252]
fields = []
with open(dic, 'r', encoding='mac_roman', newline='') as fi:
    reader = csv.reader(fi)
    next(reader)
    index = 0
    for line in reader:
        if index in indeces:
            fields.append(line[1])
        index += 1
print(fields)
# Out:
# ['HOUSEHOLD IDENTIFIER', 'ARE YOUR LIVING QUARTERS...', 'IS THERE A TELEPHONE IN THIS ', 'FAMILY INCOME', 'TOTAL NUMBER OF PERSONS LIVING ', 'REGION', 'DIVISION', 'INDIVIDUAL PRINCIPAL CITY', 'PERSONS AGE  ', 'MARITAL STATUS ', 'SEX', 'DID YOU EVER SERVE ON ACTIVE ', 'HIGHEST LEVEL OF SCHOOL ', 'RACE', 'CHANGE IN HOUSEHOLD COMPOSITION', 'HISPANIC OR NON-HISPANIC', 'COUNTRY OF BIRTH', 'CITIZENSHIP STATUS', 'LAST WEEK, DID YOU DO ANY WORK', 'LAST WEEK, DID YOU DO ANY', 'DO YOU RECEIVE ANY PAYMENTS', 'DISABILITY STATUS', 'DO YOU CURRENTLY WANT A JOB, EITHER ', 'INDUSTRY AND OCCUPATION ', 'CLASS OF WORKER', 'CLASS OF WORKER', 'COW - PRIVATE OR GOVERNMENT', 'PERIODICITY', 'HOURLY/NONHOURLY STATUS', 'WHAT IS YOUR HOURLY RATE OF PAY ON ', '(EXCLUDING OVERTIME PAY, TIPS AND ', 'HOURLY PAY - TOP CODE', 'USUAL HOURS', 'CALCULATED WEEKLY OVERTIME AMOUNT', 'ON THIS JOB, ARE YOU A MEMBER OF A ', 'ON THIS JOB ARE YOU COVERED BY A UNION ', 'PRESENCE OF OWN CHILDREN <18 YEARS ', 'Number of own children <18 years of age ']

# %%
with open(data, 'r', encoding='mac_roman') as fi, open('cleaned1.csv', 'w', encoding='mac_roman') as fo:
    reader = csv.reader(fi)
    writer = csv.writer(fo)
    writer.writerow(fields)
    next(reader)
    
    for line in reader:
        # skip missing race and income values 
        if (line[47] == '-1' or line[11] == '-1'):
            continue
        else:
            writer.writerow([line[i] for i in range(len(line)) if i in indeces])

# %%
with open('cleaned1.csv', 'r', encoding='mac_roman') as fi:
    reader = csv.reader(fi)
    missing = 0
    race = set()
    next(reader)
    
    for line in reader:
        if (line[3] == '-1' or line[13] == '-1' or int(line[3]) == -1 or int(line[13]) == -1):
            missing += 1
            race.add(line[13])
            row.add("".join(line[1:5]+line[8:]))
    print(missing)
    print(race)
# Out:
# 0
# set()

# %%
with open('cleaned1.csv', 'r', encoding='mac_roman') as fi:
    reader = csv.reader(fi)
    headers = next(reader)
    image = {i: set() for i in range(len(headers))}
    
    for line in reader:
        for i in range(len(headers)):
            image[i].add(line[i])
for i in range(len(headers)):
    print(i, headers[i], len(image[i]), list(image[i])[0:15])
# Out:
# 0 HOUSEHOLD IDENTIFIER 51075 ['292072651106051', '073061574500731', '035395101860402', '152031703301561', '900221583310093', '012925201370009', '905311233010606', '401135010830376', '551260008600379', '471895003200165', '309436052810028', '702373701770202', '095655501120002', '901285190301136', '050110640899379']
# 1 ARE YOUR LIVING QUARTERS... 1 ['-1']
# 2 IS THERE A TELEPHONE IN THIS  2 [' 1', ' 2']
# 3 FAMILY INCOME 16 ['13', ' 1', ' 8', '12', '15', ' 2', ' 4', ' 3', '16', '11', ' 6', ' 5', ' 7', '14', '10']
# 4 TOTAL NUMBER OF PERSONS LIVING  14 ['13', ' 1', ' 8', '12', ' 2', ' 4', ' 3', '11', ' 6', ' 5', '14', ' 9', '10', ' 7']
# 5 REGION 4 [' 3', ' 1', ' 4', ' 2']
# 6 DIVISION 9 ['7', '1', '5', '2', '4', '8', '3', '9', '6']
# 7 INDIVIDUAL PRINCIPAL CITY 8 ['1', '7', '5', '2', '6', '4', '3', '0']
# 8 PERSONS AGE   82 [' 3', '25', '60', '22', '39', '27', '70', '36', '41', '66', '52', '55', '48', '29', '67']
# 9 MARITAL STATUS  7 [' 1', ' 2', '-1', ' 4', ' 3', ' 6', ' 5']
# 10 SEX 2 [' 1', ' 2']
# 11 DID YOU EVER SERVE ON ACTIVE  3 ['-1', ' 1', ' 2']
# 12 HIGHEST LEVEL OF SCHOOL  17 ['38', '35', '44', '32', '46', '-1', '42', '39', '45', '33', '36', '40', '37', '41', '34']
# 13 RACE 25 [' 3', '25', '22', '14', '10', '17', ' 1', '11', '23', ' 5', '21', '13', '19', '15', '26']
# 14 CHANGE IN HOUSEHOLD COMPOSITION 6 [' 1', ' 2', ' 3', '-1', ' 5', ' 9']
# 15 HISPANIC OR NON-HISPANIC 2 [' 1', ' 2']
# 16 COUNTRY OF BIRTH 161 [' 69', '149', '110', '126', '128', '228', '150', '399', '329', '300', '164', '235', '508', '108', '148']
# 17 CITIZENSHIP STATUS 5 [' 1', ' 2', ' 4', ' 3', ' 5']
# 18 LAST WEEK, DID YOU DO ANY WORK 8 [' 1', ' 2', '-1', ' 3', ' 4', '-3', ' 5', '-2']
# 19 LAST WEEK, DID YOU DO ANY 5 [' 1', ' 2', '-1', '-3', '-2']
# 20 DO YOU RECEIVE ANY PAYMENTS 4 ['-1', ' 1', '-2', ' 2']
# 21 DISABILITY STATUS 6 [' 1', ' 2', '-1', ' 3', '-3', '-2']
# 22 DO YOU CURRENTLY WANT A JOB, EITHER  6 [' 1', ' 2', '-1', '-3', ' 3', '-2']
# 23 INDUSTRY AND OCCUPATION  3 ['-1', ' 1', ' 0']
# 24 CLASS OF WORKER 7 [' 1', ' 2', ' 4', '-1', ' 3', ' 5', ' 6']
# 25 CLASS OF WORKER 6 [' 1', ' 2', '-1', ' 4', ' 3', ' 5']
# 26 COW - PRIVATE OR GOVERNMENT 3 ['-1', ' 1', ' 2']
# 27 PERIODICITY 8 [' 1', ' 2', '-1', ' 3', ' 4', ' 6', ' 5', ' 7']
# 28 HOURLY/NONHOURLY STATUS 3 ['-1', ' 1', ' 2']
# 29 WHAT IS YOUR HOURLY RATE OF PAY ON  11 ['9615', '1286', '2500', '6352', '1500', '  -1', '1300', '  -2', '2400', '2800', '2300']
# 30 (EXCLUDING OVERTIME PAY, TIPS AND  446 ['2440', '2450', '2400', '4563', '1150', '1100', ' 885', '2472', '1248', ' 800', '3972', '4807', ' 335', ' 375', '1270']
# 31 HOURLY PAY - TOP CODE 2 ['1', '0']
# 32 USUAL HOURS 70 ['84', ' 3', '25', '60', '39', '22', '27', '70', '36', '66', '41', '55', '48', '52', '14']
# 33 CALCULATED WEEKLY OVERTIME AMOUNT 274 ['   16000', '   72000', '   24000', '   13500', '   19750', '   12852', '    5000', '    4950', '   32500', '    2535', '    3225', '   27300', '    4250', '   16485', '    1800']
# 34 ON THIS JOB, ARE YOU A MEMBER OF A  3 ['-1', ' 1', ' 2']
# 35 ON THIS JOB ARE YOU COVERED BY A UNION  3 ['-1', ' 1', ' 2']
# 36 PRESENCE OF OWN CHILDREN <18 YEARS  16 ['13', ' 1', ' 0', ' 8', '15', '12', ' 2', ' 4', ' 3', '11', ' 5', ' 6', '14', ' 9', '10']
# 37 Number of own children <18 years of age  11 [' 1', ' 0', ' 8', ' 2', ' 4', ' 3', ' 5', ' 6', ' 9', '10', ' 7']

# %%
# making income binary and binning continuous stuff (literally just age lol)
income = []
age = []
with open('cleaned1.csv', 'r', encoding='mac_roman') as fi:
    reader = csv.reader(fi)
    next(reader)
        
    for line in reader:
        income.append(int(line[3]))
        age.append(int(line[8]))

# %%
import numpy as np
income_q = {1:np.quantile(income, 0.25), 2:np.quantile(income, 0.50), 
            3:np.quantile(income, 0.75), 4:np.quantile(income, 1), 5:np.quantile(income, 0.05)}
age_q = {1:np.quantile(age, 0.25), 2:np.quantile(age, 0.50), 
            3:np.quantile(age, 0.75), 4:np.quantile(age, 1)}

# %%
with open('cleaned1.csv', 'r', encoding='mac_roman') as fi, open('cleaned5.csv', 'w', encoding='mac_roman') as fo:
    reader = csv.reader(fi)
    writer = csv.writer(fo)
    
    # prepare the headers
    headers = next(reader)
    headers.append('race-binary')
    delete = [29, 30, 31, 32, 33]
    headers = headers[0:29] + headers[34:]
    print(headers)
    writer.writerow(headers)
    
    for line in reader:
        
        # make race binary
        line.append('1' if line[13] == ' 1' else '0')
        
        # bin income - 0 for low income and 1 for high
        # we're treating low income as bottom 5%
        if int(line[3]) < income_q[3]:
            line[3] = '0'
        else:
            line[3] = '1'
        
        # bin age by quartile: 0, 1, 2, 3
        if int(line[8]) < age_q[1]:
            line[8] = '0'
        elif int(line[8]) < age_q[2]:
            line[8] = '1'
        elif int(line[8]) < age_q[3]:
            line[8] = '2'
        else:
            line[8] = '3'
        
        # deal with country of origin (bin all international values together)
        # international (100-554) = 1
        if 100 <= int(line[16]) and int(line[16]) <= 554:
            line[16] = '1'
            
        # remove the obvious stuff 
        line = line[0:29] + line[34:]
        
        writer.writerow(line)
# Out:
# ['HOUSEHOLD IDENTIFIER', 'ARE YOUR LIVING QUARTERS...', 'IS THERE A TELEPHONE IN THIS ', 'FAMILY INCOME', 'TOTAL NUMBER OF PERSONS LIVING ', 'REGION', 'DIVISION', 'INDIVIDUAL PRINCIPAL CITY', 'PERSONS AGE  ', 'MARITAL STATUS ', 'SEX', 'DID YOU EVER SERVE ON ACTIVE ', 'HIGHEST LEVEL OF SCHOOL ', 'RACE', 'CHANGE IN HOUSEHOLD COMPOSITION', 'HISPANIC OR NON-HISPANIC', 'COUNTRY OF BIRTH', 'CITIZENSHIP STATUS', 'LAST WEEK, DID YOU DO ANY WORK', 'LAST WEEK, DID YOU DO ANY', 'DO YOU RECEIVE ANY PAYMENTS', 'DISABILITY STATUS', 'DO YOU CURRENTLY WANT A JOB, EITHER ', 'INDUSTRY AND OCCUPATION ', 'CLASS OF WORKER', 'CLASS OF WORKER', 'COW - PRIVATE OR GOVERNMENT', 'PERIODICITY', 'HOURLY/NONHOURLY STATUS', 'ON THIS JOB, ARE YOU A MEMBER OF A ', 'ON THIS JOB ARE YOU COVERED BY A UNION ', 'PRESENCE OF OWN CHILDREN <18 YEARS ', 'Number of own children <18 years of age ', 'race-binary']
