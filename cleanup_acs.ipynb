# %%
import csv

dic = 'data/PUMSDataDict15.txt'
file = 'data/ss15pusa/ss15pusa.csv'

fields = []
with open(dic, 'r', encoding='mac_roman', newline='') as fi:
    index = 0
    line = fi.readline()
    flag = False
    prev = None
    while (line):
        if not flag and (line.find('PERSON RECORD') != -1):
            flag = True
            continue
        if flag and line[0:3].isupper() and line[0:2].find(' ') == -1 and prev=="\n":
            desc = fi.readline()
            print(index, line.split('\t')[0]+ " " + desc)
            index += 1
            fields.append(line.split('\t')[0]+ " " + desc)
        prev = line
        line = fi.readline()
# Out:
# 0 PERSON RECORD
#
#
# 1 SERIALNO    	Housing unit/GQ person serial number
#
# 2 SPORDER 	Person number
#
# 3 PUMA 	Public use microdata area code (PUMA) based on 2010 Census definition
#
# 4 ST 	State Code
#
# 5 ADJINC Adjustment factor for income and earnings dollar amounts (6 implied decimal places)
#
# 6 PWGTP 	Person's weight
#
# 7 AGEP 	Age
#
# 8 CIT 	Citizenship status
#
# 9 CITWP 	Year of naturalization write-in
#
# 10 COW 	Class of worker
#
# 11 DDRS 	Self-care difficulty
#
# 12 DEAR 	Hearing difficulty
#
# 13 DEYE 	Vision difficulty
#
# 14 DOUT 	Independent living difficulty
#
# 15 DPHY 	Ambulatory difficulty
#
# 16 DRAT 	Veteran service connected disability rating (percentage)
#
# 17 DRATX 	Veteran service connected disability rating (checkbox)
#
# 18 DREM 	Cognitive difficulty
#
# 19 ENG 	Ability to speak English
#
# 20 FER 	Gave birth to child within the past 12 months
#
# 21 GCL 	Grandparents living with grandchildren
#
# 22 GCM 	Length of time responsible for grandchildren
#
# 23 GCR 	Grandparents responsible for grandchildren
#
# 24 HINS1 	Insurance through a current or former employer or union
#
# 25 HINS2 	Insurance purchased directly from an insurance company
#
# 26 HINS3 	Medicare, for people 65 and older, or people with certain disabilities
#
# 27 HINS4 	Medicaid, Medical Assistance, or any kind of government-assistance plan
#
# 28 HINS5 	TRICARE or other military health care
#
# 29 HINS6 	VA (including those who have ever used or enrolled for VA health care)
#
# 30 HINS7 	Indian Health Service
#
# 31 INTP 	Interest, dividends, and net rental income past 12 months (signed)
#
# 32 JWMNP 	Travel time to work
#
# 33 JWRIP 	Vehicle occupancy
#
# 34 JWTR 	Means of transportation to work
#
# 35 LANX 	Language other than English spoken at home
#
# 36 MAR 	Marital status
#
# 37 MARHD 	Divorced in the past 12 months
#
# 38 MARHM 	Married in the past 12 months
#
# 39 MARHT 	Number of times married
#
# 40 MARHW 	Widowed in the past 12 months
#
# 41 MARHYP 	Year last married
#
# 42 MIG 	Mobility status (lived here 1 year ago)
#
# 43 MIL 	Military service
#
# 44 MLPA 	Served September 2001 or later
#
# 45 MLPB 	Served August 1990 - August 2001 (including Persian Gulf War)
#
# 46 MLPCD 	Served May 1975 - July 1990
#
# 47 MLPE 	Served Vietnam era (August 1964 - April 1975)
#
# 48 MLPFG 	Served February 1955 - July 1964
#
# 49 MLPH 	Served Korean War (July 1950 - January 1955)
#
# 50 MLPI 	Served January 1947 - June 1950
#
# 51 MLPJ 	Served World War II (December 1941 - December 1946)
#
# 52 MLPK 	Served November 1941 or earlier
#
# 53 NWAB 	Temporary absence from work
#
# 54 NWAV 	Available for work
#
# 55 NWLA 	On layoff from work
#
# 56 NWLK 	Looking for work
#
# 57 NWRE 	Informed of recall
#
# 58 OIP 	All other income past 12 months
#
# 59 PAP 	Public assistance income past 12 months
#
# 60 RELP 	Relationship
#
# 61 RETP 	Retirement income past 12 months
#
# 62 SCH 	School enrollment
#
# 63 SCHG 	Grade level attending
#
# 64 SCHL 	Educational attainment
#
# 65 SEMP 	Self-employment income past 12 months (signed)
#
# 66 SEX 	Sex
#
# 67 SSIP 	Supplementary Security Income past 12 months
#
# 68 SSP
#
# 69 WAGP 	Wages or salary income past 12 months
#
# 70 WKHP 	Usual hours worked per week past 12 months
#
# 71 WKL 	When last worked
#
# 72 WKW 	Weeks worked during past 12 months
#
# 73 WRK 	Worked last week
#
# 74 YOEP 	Year of entry
#
# 75 ANC 	Ancestry recode
#
# 76 ANC1P 	Recoded Detailed Ancestry - first entry
#
# 77 ANC2P 	Recoded Detailed Ancestry - second entry
#
# 78 DECADE 	Decade of entry
#
# 79 DIS 	Disability recode
#
# 80 DRIVESP 	Number of vehicles calculated from JWRI
#
# 81 ESP 	Employment status of parents
#
# 82 ESR 	Employment status recode
#
# 83 FOD1P 	Recoded field of degree - first entry
#
# 84 FOD2P 	Recoded field of degree - second entry
#
# 85 HICOV 	Health insurance coverage recode
#
# 86 HISP 	Recoded detailed Hispanic origin
#
# 87 INDP 	Industry recode for 2013 and later based on 2012 IND codes
#
# 88 JWAP 	Time of arrival at work - hour and minute
#
# 89 JWDP 	Time of departure for work - hour and minute
#
# 90 LANP 	Language spoken at home
#
# 91 MIGPUMA 	Migration PUMA based on 2010 Census definition
#
# 92 MIGSP 	Migration recode - State or foreign country code
#
# 93 MSP 	Married, spouse present/spouse absent
#
# 94 NAICSP 	NAICS Industry recode for 2013 and later based on 2012 NAICS codes
#
# 95 NATIVITY 	Nativity
#
# 96 NOP 	Nativity of parent
#
# 97 OC 	Own child
#
# 98 OCCP 	Occupation recode for 2012 and later based on 2010 OCC codes
#
# 99 PAOC 	Presence and age of own children
#
# 100 PERNP 	Total person's earnings
#
# 101 PINCP 	Total person's income (signed)
#
# 102 POBP 	Place of birth (Recode)
#
# 103 POVPIP 	Income-to-poverty ratio recode
#
# 104 POWPUMA 	Place of work PUMA based on 2010 Census definition
#
# 105 POWSP 	Place of work - State or foreign country recode
#
# 106 PRIVCOV 	Private health insurance coverage recode
#
# 107 PUBCOV 	Public health coverage recode
#
# 108 QTRBIR 	Quarter of birth
#
# 109 RAC1P 	Recoded detailed race code
#
# 110 RAC2P 	Recoded detailed race code
#
# 111 RAC3P 	Recoded detailed race code
#
# 112 RACAIAN 	American Indian and Alaska Native recode (American Indian and
#
# 113 RACASN 	Asian recode (Asian alone or in combination with one or more
#
# 114 RACBLK 	Black or African American recode (Black alone or in
#
# 115 RACNH 	Native Hawaiian recode (Native Hawaiian alone or in combination with
#
# 116 RACNUM 	Number of major race groups represented
#
# 117 RACPI 	Other Pacific Islander recode (Other Pacific Islander alone or in
#
# 118 RACSOR 	Some other race recode (Some other race alone or in
#
# 119 RACWHT 	White recode (White alone or in combination with one or more
#
# 120 RC 	Related child
#
# 121 SCIENGP 	Field of Degree Science and Engineering Flag ñ NSF Definition
#
# 122 SCIENGRLP 	Field of Degree Science and Engineering Related Flag ñ NSF Definition
#
# 123 SFN 	Subfamily number
#
# 124 SFR 	Subfamily relationship
#
# 125 SOCP 	SOC Occupation code for 2012 and later based on 2010 SOC codes
#
# 126 VPS 	Veteran period of service
#
# 127 WAOB 	World area of birth ****
#
# 128 FAGEP 	Age allocation flag
#
# 129 FANCP 	Ancestry allocation flag
#
# 130 FCITP 	Citizenship allocation flag
#
# 131 FCITWP 	Year of naturalization write-in allocation flag
#
# 132 FCOWP 	Class of worker allocation flag
#
# 133 FDDRSP 	Self-care difficulty allocation flag
#
# 134 FDEARP 	Hearing difficulty allocation flag
#
# 135 FDEYEP 	Vision difficulty allocation flag
#
# 136 FDISP 	Disability recode allocation flag
#
# 137 FDOUTP 	Independent living difficulty allocation flag
#
# 138 FDPHYP 	Ambulatory difficulty allocation flag
#
# 139 FDRATP 	Disability rating percentage allocation flag
#
# 140 FDRATXP 	Disability rating checkbox allocation flag
#
# 141 FDREMP 	Cognitive difficulty allocation flag
#
# 142 FENGP 	Ability to speak English allocation flag
#
# 143 FESRP 	Employment status recode allocation flag
#
# 144 FFERP 	Gave birth to child within the past 12 months allocation flag
#
# 145 FFODP 	Field of Degree allocation flag
#
# 146 FGCLP 	Grandparents living with grandchildren allocation flag
#
# 147 FGCMP 	Length of time responsible for grandchildren allocation flag
#
# 148 FGCRP 	Grandparents responsible for grandchildren allocation flag
#
# 149 FHICOVP 	Health insurance coverage recode allocation flag
#
# 150 FHINS1P 	Insurance through a current or former employer or union allocation flag
#
# 151 FHINS2P 	Insurance purchased directly from an insurance company allocation flag
#
# 152 FHINS3P 	Medicare, for people 65 or older, or people with certain disabilities
#
# 153 FHINS4C 	Medicaid coverage given through the eligibility coverage edit
#
# 154 FHINS4P 	Medicaid, medical assistance, or any kind of government-assistance plan
#
# 155 FHINS5C 	TRICARE coverage given through the eligibility coverage edit
#
# 156 FHINS5P 	TRICARE or other military health care allocation flag
#
# 157 FHINS6P 	VA (including those who have ever used or enrolled for VA health care)
#
# 158 FHINS7P 	Indian health service allocation flag
#
# 159 FHISP 	Detailed Hispanic origin allocation flag
#
# 160 FINDP 	Industry allocation flag
#
# 161 FINTP 	Interest, dividend, and net rental income allocation flag
#
# 162 FJWDP 	Time of departure to work allocation flag
#
# 163 FJWMNP 	Travel time to work allocation flag
#
# 164 FJWRIP 	Vehicle occupancy allocation flag
#
# 165 FJWTRP 	Means of transportation to work allocation flag
#
# 166 FLANP 	Language spoken at home allocation flag
#
# 167 FLANXP 	Language other than English allocation flag
#
# 168 FMARP 	Marital status allocation flag
#
# 169 FMARHDP 	Divorced in the past 12 months allocation flag
#
# 170 FMARHMP 	Married in the past 12 months allocation flag
#
# 171 FMARHTP 	Times married allocation flag
#
# 172 FMARHWP 	Widowed in the past 12 months allocation flag
#
# 173 FMARHYP 	Year last married allocation flag
#
# 174 FMIGP 	Mobility status allocation flag
#
# 175 FMIGSP 	Migration state allocation flag
#
# 176 FMILPP 	Military periods of service allocation flag
#
# 177 FMILSP 	Military service allocation flag
#
# 178 FOCCP 	Occupation allocation flag
#
# 179 FOIP 	All other income allocation flag
#
# 180 FPAP 	Public assistance income allocation flag
#
# 181 FPERNP 	Total personís earnings allocation flag
#
# 182 FPINCP 	Total personís income (signed) allocation flag
#
# 183 FPOBP 	Place of birth allocation flag
#
# 184 FPOWSP 	Place of work state allocation flag
#
# 185 FPRIVCOVP  	Private health insurance coverage recode allocation flag
#
# 186 FPUBCOVP   	Public health coverage recode allocation flag
#
# 187 FRACP 	Detailed race allocation flag
#
# 188 FRELP 	Relationship allocation flag
#
# 189 FRETP 	Retirement income allocation flag
#
# 190 FSCHGP 	Grade attending allocation flag
#
# 191 FSCHLP 	Highest education allocation flag
#
# 192 FSCHP 	School enrollment allocation flag
#
# 193 FSEMP 	Self-employment income allocation flag
#
# 194 FSEXP 	Sex allocation flag
#
# 195 FSSIP 	Supplementary Security Income allocation flag
#
# 196 FSSP 	Social Security income allocation flag
#
# 197 FWAGP 	Wages and salary income allocation flag
#
# 198 FWKHP 	Usual hours worked per week past 12 months allocation flag
#
# 199 FWKLP 	Last worked allocation flag
#
# 200 FWKWP 	Weeks worked past 12 months allocation flag
#
# 201 FWRKP 	Worked last week allocation flag
#
# 202 FYOEP 	Year of entry allocation flag
#
# 203 PWGTP1 	Person's Weight replicate 1
#
# 204 PWGTP2 	Person's Weight replicate 2
#
# 205 PWGTP3 	Person's Weight replicate 3
#
# 206 PWGTP4 	Person's Weight replicate 4
#
# 207 PWGTP5 	Person's Weight replicate 5
#
# 208 PWGTP6 	Person's Weight replicate 6
#
# 209 PWGTP7 	Person's Weight replicate 7
#
# 210 PWGTP8 	Person's Weight replicate 8
#
# 211 PWGTP9 	Person's Weight replicate 9
#
# 212 PWGTP10 	Person's Weight replicate 10
#
# 213 PWGTP11 	Person's Weight replicate 11
#
# 214 PWGTP12 	Person's Weight replicate 12
#
# 215 PWGTP13 	Person's Weight replicate 13
#
# 216 PWGTP14 	Person's Weight replicate 14
#
# 217 PWGTP15 	Person's Weight replicate 15
#
# 218 PWGTP16 	Person's Weight replicate 16
#
# 219 PWGTP17 	Person's Weight replicate 17
#
# 220 PWGTP18 	Person's Weight replicate 18
#
# 221 PWGTP19 	Person's Weight replicate 19
#
# 222 PWGTP21 	Person's Weight replicate 21
#
# 223 PWGTP22 	Person's Weight replicate 22
#
# 224 PWGTP23 	Person's Weight replicate 23
#
# 225 PWGTP24 	Person's Weight replicate 24
#
# 226 PWGTP25 	Person's Weight replicate 25
#
# 227 PWGTP26 	Person's Weight replicate 26
#
# 228 PWGTP27 	Person's Weight replicate 27
#
# 229 PWGTP28 	Person's Weight replicate 28
#
# 230 PWGTP29 	Person's Weight replicate 29
#
# 231 PWGTP30 	Person's Weight replicate 30
#
# 232 PWGTP31 	Person's Weight replicate 31
#
# 233 PWGTP32 	Person's Weight replicate 32
#
# 234 PWGTP34 	Person's Weight replicate 34
#
# 235 PWGTP35 	Person's Weight replicate 35
#
# 236 PWGTP36 	Person's Weight replicate 36
#
# 237 PWGTP37 	Person's Weight replicate 37
#
# 238 PWGTP38 	Person's Weight replicate 38
#
# 239 PWGTP39 	Person's Weight replicate 39
#
# 240 PWGTP40 	Person's Weight replicate 40
#
# 241 PWGTP41 	Person's Weight replicate 41
#
# 242 PWGTP42 	Person's Weight replicate 42
#
# 243 PWGTP43 	Person's Weight replicate 43
#
# 244 PWGTP44 	Person's Weight replicate 44
#
# 245 PWGTP45 	Person's Weight replicate 45
#
# 246 PWGTP46 	Person's Weight replicate 46
#
# 247 PWGTP47 	Person's Weight replicate 47
#
# 248 PWGTP48 	Person's Weight replicate 48
#
# 249 PWGTP49 	Person's Weight replicate 49
#
# 250 PWGTP50 	Person's Weight replicate 50
#
# 251 PWGTP51 	Person's Weight replicate 51
#
# 252 PWGTP52 	Person's Weight replicate 52
#
# 253 PWGTP53 	Person's Weight replicate 53
#
# 254 PWGTP54 	Person's Weight replicate 54
#
# 255 PWGTP55 	Person's Weight replicate 55
#
# 256 PWGTP56 	Person's Weight replicate 56
#
# 257 PWGTP57 	Person's Weight replicate 57
#
# 258 PWGTP59 	Person's Weight replicate 59
#
# 259 PWGTP60 	Person's Weight replicate 60
#
# 260 PWGTP61 	Person's Weight replicate 61
#
# 261 PWGTP62 	Person's Weight replicate 62
#
# 262 PWGTP63 	Person's Weight replicate 63
#
# 263 PWGTP64 	Person's Weight replicate 64
#
# 264 PWGTP65 	Person's Weight replicate 65
#
# 265 PWGTP66 	Person's Weight replicate 66
#
# 266 PWGTP67 	Person's Weight replicate 67
#
# 267 PWGTP68 	Person's Weight replicate 68
#
# 268 PWGTP69 	Person's Weight replicate 69
#
# 269 PWGTP70 	Person's Weight replicate 70
#
# 270 PWGTP71 	Person's Weight replicate 71
#
# 271 PWGTP72 	Person's Weight replicate 72
#
# 272 PWGTP73 	Person's Weight replicate 73
#
# 273 PWGTP74 	Person's Weight replicate 74
#
# 274 PWGTP75 	Person's Weight replicate 75
#
# 275 PWGTP76 	Person's Weight replicate 76
#
# 276 PWGTP77 	Person's Weight replicate 77
#
# 277 PWGTP78 	Person's Weight replicate 78
#
# 278 PWGTP79 	Person's Weight replicate 79
#
# 279 PWGTP80 	Person's Weight replicate 80

# %%
indeces = [4, 7, 8, 10, 11, 12, 13, 14, 18, 19, 20, 24, 25, 26, 27, 28, 29, 30, 32, 34, 35, 36, 37, 41, 
           42, 59, 62, 64, 66, 81, 84, 88, 91, 96, 97, 102, 103, 105, 110]
indeces = [index for index in indeces]
income = 101
race = 110
fields = [fields[i] for i in indeces]
for i in range(len(fields)):
    print(i, fields[i])
# Out:
# 0 ST 	State Code
#
# 1 AGEP 	Age
#
# 2 CIT 	Citizenship status
#
# 3 COW 	Class of worker
#
# 4 DDRS 	Self-care difficulty
#
# 5 DEAR 	Hearing difficulty
#
# 6 DEYE 	Vision difficulty
#
# 7 DOUT 	Independent living difficulty
#
# 8 DREM 	Cognitive difficulty
#
# 9 ENG 	Ability to speak English
#
# 10 FER 	Gave birth to child within the past 12 months
#
# 11 HINS1 	Insurance through a current or former employer or union
#
# 12 HINS2 	Insurance purchased directly from an insurance company
#
# 13 HINS3 	Medicare, for people 65 and older, or people with certain disabilities
#
# 14 HINS4 	Medicaid, Medical Assistance, or any kind of government-assistance plan
#
# 15 HINS5 	TRICARE or other military health care
#
# 16 HINS6 	VA (including those who have ever used or enrolled for VA health care)
#
# 17 HINS7 	Indian Health Service
#
# 18 JWMNP 	Travel time to work
#
# 19 JWTR 	Means of transportation to work
#
# 20 LANX 	Language other than English spoken at home
#
# 21 MAR 	Marital status
#
# 22 MARHD 	Divorced in the past 12 months
#
# 23 MARHYP 	Year last married
#
# 24 MIG 	Mobility status (lived here 1 year ago)
#
# 25 PAP 	Public assistance income past 12 months
#
# 26 SCH 	School enrollment
#
# 27 SCHL 	Educational attainment
#
# 28 SEX 	Sex
#
# 29 ESP 	Employment status of parents
#
# 30 FOD2P 	Recoded field of degree - second entry
#
# 31 JWAP 	Time of arrival at work - hour and minute
#
# 32 MIGPUMA 	Migration PUMA based on 2010 Census definition
#
# 33 NOP 	Nativity of parent
#
# 34 OC 	Own child
#
# 35 POBP 	Place of birth (Recode)
#
# 36 POVPIP 	Income-to-poverty ratio recode
#
# 37 POWSP 	Place of work - State or foreign country recode
#
# 38 RAC2P 	Recoded detailed race code

# %%
with open(file, 'r', encoding='mac_roman') as fi, open('cleaned_acs_1.csv', 'w', encoding='mac_roman') as fo:
    reader = csv.reader(fi)
    writer = csv.writer(fo)
    count = 0
    
    for line in reader:
        # remove missing race and income values
        if (line[race] != '' and line[income] != ''):
            count += 1
            if (count % 25000 == 0):
                print(count)
            data = [line[i] for i in indeces]
            #recode missing as -1
            writer.writerow(['-1'if entry == '' else entry for entry in data])
# Out:
# 25000
# 50000
# 75000
# 100000
# 125000
# 150000
# 175000
# 200000
# 225000
# 250000
# 275000
# 300000
# 325000
# 350000
# 375000
# 400000
# 425000
# 450000
# 475000
# 500000
# 525000
# 550000
# 575000
# 600000
# 625000
# 650000
# 675000
# 700000
# 725000
# 750000
# 775000
# 800000
# 825000
# 850000
# 875000
# 900000
# 925000
# 950000
# 975000
# 1000000
# 1025000
# 1050000
# 1075000
# 1100000
# 1125000
# 1150000
# 1175000
# 1200000
# 1225000
# 1250000
# 1275000
# 1300000
# 1325000

# %%
with open('cleaned_acs_1.csv', 'r', encoding='mac_roman') as fi:
    reader = csv.reader(fi)
    headers = next(reader)
    image = {i: set() for i in range(len(headers))}
    
    for line in reader:
        for i in range(len(headers)):
            image[i].add(line[i])
for i in range(len(headers)):
    print(i, headers[i], len(image[i]), list(image[i])[0:15])
# Out:
# 0 ST 25 ['01', '02', '11', '28', '16', '22', '10', '19', '25', '18', '24', '05', '04', '12', '13']
# 1 AGEP 81 ['28', '56', '31', '49', '16', '84', '41', '87', '65', '79', '62', '57', '44', '68', '43']
# 2 CIT 5 ['2', '4', '1', '5', '3']
# 3 COW 10 ['2', '6', '4', '1', '9', '7', '8', '5', '-1', '3']
# 4 DDRS 2 ['2', '1']
# 5 DEAR 2 ['2', '1']
# 6 DEYE 2 ['2', '1']
# 7 DOUT 2 ['2', '1']
# 8 DREM 2 ['2', '1']
# 9 ENG 5 ['2', '4', '1', '-1', '3']
# 10 FER 3 ['-1', '2', '1']
# 11 HINS1 2 ['2', '1']
# 12 HINS2 2 ['2', '1']
# 13 HINS3 2 ['2', '1']
# 14 HINS4 2 ['2', '1']
# 15 HINS5 2 ['2', '1']
# 16 HINS6 2 ['2', '1']
# 17 HINS7 2 ['2', '1']
# 18 JWMNP 131 ['156', '155', '145', '041', '125', '025', '090', '024', '026', '072', '030', '038', '061', '039', '165']
# 19 JWTR 13 ['01', '11', '02', '04', '03', '12', '06', '07', '08', '10', '09', '05', '-1']
# 20 LANX 2 ['2', '1']
# 21 MAR 5 ['2', '4', '1', '5', '3']
# 22 MARHD 3 ['-1', '2', '1']
# 23 MARHYP 83 ['1940', '1967', '1966', '2014', '2004', '2011', '1943', '2010', '1977', '1947', '1979', '1970', '1954', '2007', '1945']
# 24 MIG 3 ['2', '3', '1']
# 25 PAP 306 ['04900', '00530', '04600', '11900', '05200', '04000', '00100', '00690', '02300', '00850', '08600', '13100', '00200', '14000', '20000']
# 26 SCH 3 ['2', '3', '1']
# 27 SCHL 24 ['11', '01', '02', '03', '16', '22', '10', '19', '18', '24', '05', '04', '13', '12', '23']
# 28 SEX 2 ['2', '1']
# 29 ESP 9 ['2', '6', '4', '1', '7', '8', '5', '-1', '3']
# 30 FOD1P 174 ['2402', '2300', '2415', '2411', '1100', '6209', '2412', '6107', '5002', '5003', '6201', '6299', '3701', '6110', '5301']
# 31 INDP 268 ['2490', '3780', '7280', '4490', '6380', '3070', '5470', '8980', '9170', '4170', '3180', '8580', '4680', '8790', '7080']
# 32 LANP 110 ['663', '701', '993', '665', '666', '780', '653', '624', '819', '744', '704', '620', '677', '650', '724']
# 33 NATIVITY 2 ['2', '1']
# 34 NOP 9 ['2', '6', '4', '1', '5', '7', '8', '-1', '3']
# 35 PINCP 16273 ['000037930', '000135020', '000016290', '000064490', '000141400', '000003790', '000069640', '000058140', '000025630', '000113700', '000842000', '000350800', '000165700', '000110280', '000026104']
# 36 POBP 215 ['156', '218', '041', '523', '414', '025', '313', '399', '024', '026', '072', '030', '211', '127', '038']
# 37 POWPUMA 211 ['02690', '04900', '04600', '04000', '05200', '00100', '00690', '02300', '03290', '03601', '00200', '20000', '03100', '03700', '11000']
# 38 RAC1P 9 ['2', '6', '4', '1', '7', '8', '5', '9', '3']

# %%
# bin continuous values - need to preprocess data for that 
age = 1
age_l = []
travelt = 18
travelt_l = []
pap = 25
pap_l = []
income = 35
income_l = []
race= 38

with open('cleaned_acs_1.csv', 'r', encoding='mac_roman') as fi:
    reader = csv.reader(fi)
    next(reader)
        
    for line in reader:
        age_l.append(int(line[age]))
        travelt_l.append(int(line[travelt]))
        pap_l.append(int(line[pap]))
        income_l.append(int(line[income]))

# %%
import numpy as np
income_q = {1:np.quantile(income_l, 0.25), 2:np.quantile(income_l, 0.50), 
            3:np.quantile(income_l, 0.75), 4:np.quantile(income_l, 1), 5:np.quantile(income_l, 0.05)}
age_q = {1:np.quantile(age_l, 0.25), 2:np.quantile(age_l, 0.50), 
            3:np.quantile(age_l, 0.75), 4:np.quantile(age_l, 1)}
travelt_q = {1:np.quantile(travelt_l, 0.25), 2:np.quantile(travelt_l, 0.50), 
            3:np.quantile(travelt_l, 0.75), 4:np.quantile(travelt_l, 1)}
pap_q = {1:np.quantile(pap_l, 0.25), 2:np.quantile(pap_l, 0.50), 
            3:np.quantile(pap_l, 0.75), 4:np.quantile(pap_l, 1)}

# %%
def get_q(index, quartiles, line):
    if int(line[index]) < quartiles[1]:
        line[index] = '0'
    elif int(line[index]) < quartiles[2]:
        line[index] = '1'
    elif int(line[index]) < quartiles[3]:
        line[index] = '2'
    else:
        line[index] = '3'
    return line

with open('cleaned_acs_1.csv', 'r', encoding='mac_roman') as fi, open('cleaned_acs_2.csv', 'w', encoding='mac_roman') as fo:
    reader = csv.reader(fi)
    writer = csv.writer(fo)
    
    # prepare the headers
    headers = next(reader)
    headers.append('race-binary')
    writer.writerow(headers)
    
    for line in reader:        
        # make race binary: 1 for white, 0 otherwise 
        line.append('1' if line[race] == '1' else '0')
        
        # bin income - 0 for low income and 1 for high
        # we're treating low income as bottom 50%
        if int(line[income]) < income_q[2]:
            line[income] = '0'
        else:
            line[income] = '1'
        
        # bin age by quartile: 0, 1, 2, 3
        line = get_q(age, age_q, line)
        
        # same for travel time and pap
        line = get_q(travelt, travelt_q, line)
        line = get_q(pap, pap_q, line)
        
        writer.writerow(line)
